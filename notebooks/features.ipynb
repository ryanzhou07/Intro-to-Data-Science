# %% [markdown]
# This file will be used to find reviews, price discounts, update history over time

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
from typing import Optional, Dict, List
import csv
import random
from datetime import datetime, timezone

# %%
def find_appid(game_name: str, lookup_df: pd.DataFrame) -> Optional[int]:
    """
    Find AppID from the lookup file by matching game name
    """
    game_name_clean = game_name.strip()
    
    # Try exact match first (case insensitive)
    exact_match = lookup_df[lookup_df['name'].str.lower() == game_name_clean.lower()]
    if not exact_match.empty:
        return int(exact_match.iloc[0]['appid'])
    
    # Try partial match
    partial_match = lookup_df[lookup_df['name'].str.contains(game_name_clean, case=False, na=False, regex=False)]
    if not partial_match.empty:
        # Prefer closer matches
        for idx, row in partial_match.iterrows():
            if game_name_clean.lower() in row['name'].lower():
                return int(row['appid'])
        return int(partial_match.iloc[0]['appid'])
    
    return None

# %%
def getRawFeatures(app_id):
    url = f"https://store.steampowered.com/appreviewhistogram/{app_id}"
    response = requests.get(url).json()
    return response['results']['rollups']
df = pd.DataFrame(getRawFeatures(730))
df['date'] = pd.to_datetime(df['date'], unit = 's')
df[0:20]
# Out:
#          date  recommendations_up  recommendations_down
# 0  2012-05-01                   1                     0
# 1  2012-08-01                1630                   208
# 2  2012-09-01                1003                    88
# 3  2012-10-01                 511                    59
# 4  2012-11-01                 591                    62
# 5  2012-12-01                 867                    93
# 6  2013-01-01                 690                    78
# 7  2013-02-01                 598                    68
# 8  2013-03-01                 529                    55
# 9  2013-04-01                 495                    53
# 10 2013-05-01                1003                   128
# 11 2013-06-01                 776                    91
# 12 2013-07-01                 929                    95
# 13 2013-08-01                 728                    97
# 14 2013-09-01                 827                   100
# 15 2013-10-01                 931                   100
# 16 2013-11-01                3496                   228
# 17 2013-12-01               18983                  1008
# 18 2014-01-01               15735                   843
# 19 2014-02-01               11181                   628

# %%
results = []
lookup_df = pd.read_csv("complete_steam_lookup_2026.csv")
with open('game_list.csv', mode = 'r', newline = '') as file:
    reader = csv.reader(file)
    header = next(reader)
    for row in reader:
        app_id = find_appid(row[0], lookup_df)
        df_details = getRawFeatures(app_id)

        df = pd.DataFrame(df_details)
        if df is not None:
            df['date'] = pd.to_datetime(df['date'], unit = 's')
            df['Game'] = row[0]
        results.append(df)
        time.sleep(random.uniform(2, 5))
full_df = pd.concat(results, axis = 0, ignore_index = True)
full_df
# Out:
#            date  recommendations_up  recommendations_down              Game
# 0    2012-05-01                   1                     0  Counter-Strike 2
# 1    2012-08-01                1630                   208  Counter-Strike 2
# 2    2012-09-01                1003                    88  Counter-Strike 2
# 3    2012-10-01                 511                    59  Counter-Strike 2
# 4    2012-11-01                 591                    62  Counter-Strike 2
# ...         ...                 ...                   ...               ...
# 4951 2026-01-01                 247                   105      Black Desert
# 4952 2026-02-01                 176                    94      Black Desert
# 4953 2026-03-01                 354                   157      Black Desert
# 4954 2026-04-01                 255                   125      Black Desert
# 4955 2026-05-01                  61                    24      Black Desert
#
# [4956 rows x 4 columns]

# %%
full_df['Log(Reviews) * Positive %'] = np.log(1+full_df['recommendations_up']+full_df['recommendations_down']) * full_df['recommendations_up']/(full_df['recommendations_down']+ full_df['recommendations_up'])
full_df.to_csv('Data/Reviews.csv')

# %%
def get_updates(appid, max_window=160):
    base_url = "https://api.steampowered.com/ISteamNews/GetNewsForApp/v0002/"
    current_unix = 1780272000 
    seconds_in_month = 30 * 24 * 60 * 60 
    
    mapped_data = []
    last_total_count = None

    for i in range(max_window + 1):
        target_unix = current_unix - (i * seconds_in_month)
        
        dt_object = datetime.fromtimestamp(target_unix, tz=timezone.utc)
        date_str = dt_object.strftime('%Y-%m')
        
        params = {'appid': appid, 'count': 1, 'enddate': target_unix}
        
        try:
            time.sleep(0.5)
            response = requests.get(base_url, params=params)
            data = response.json()
            current_total_count = data['appnews']['count']
            
            if current_total_count == 0:
                break

            if last_total_count is not None:
                monthly_delta = last_total_count - current_total_count
                mapped_data.append({
                    "Date": date_str,
                    "Raw_Velocity": monthly_delta
                })
                print(f"{date_str} | Velocity: {monthly_delta}")

            last_total_count = current_total_count
            
        except Exception as e:
            print(f"Error at {date_str}: {e}")
            break
            
    return mapped_data
# Out:
# 2026-05 | Velocity: 2
# 2026-04 | Velocity: 14
# 2026-03 | Velocity: 10
# 2026-02 | Velocity: 4
# 2026-01 | Velocity: 5
# 2025-12 | Velocity: 7
# 2025-11 | Velocity: 6
# 2025-10 | Velocity: 7
# 2025-09 | Velocity: 14
# 2025-08 | Velocity: 6
# 2025-07 | Velocity: 7
# 2025-06 | Velocity: 5
# 2025-05 | Velocity: 11
# 2025-04 | Velocity: 0
# 2025-03 | Velocity: 5
# 2025-02 | Velocity: 3
# 2025-01 | Velocity: 13
# 2024-12 | Velocity: 5
# 2024-11 | Velocity: 10
# 2024-10 | Velocity: 9
# 2024-09 | Velocity: 7
# 2024-08 | Velocity: 7
# 2024-07 | Velocity: 4
# 2024-06 | Velocity: 9
# 2024-05 | Velocity: 7
# 2024-04 | Velocity: 10
# 2024-03 | Velocity: 8
# 2024-02 | Velocity: 5
# 2024-01 | Velocity: 6
# 2023-12 | Velocity: 5
# 2023-11 | Velocity: 8
# 2023-10 | Velocity: 9
# 2023-09 | Velocity: 23
# 2023-08 | Velocity: 13
# 2023-07 | Velocity: 18
# 2023-06 | Velocity: 8
# 2023-05 | Velocity: 15
# 2023-04 | Velocity: 28
# 2023-03 | Velocity: 18
# 2023-02 | Velocity: 23
# 2023-01 | Velocity: 9
# 2022-12 | Velocity: 0
# 2022-11 | Velocity: 5
# 2022-10 | Velocity: 14
# 2022-09 | Velocity: 5
# 2022-08 | Velocity: 8
# 2022-07 | Velocity: 13
# 2022-06 | Velocity: 10
# 2022-05 | Velocity: 10
# 2022-04 | Velocity: 17
# 2022-03 | Velocity: 10
# 2022-02 | Velocity: 6
# 2022-01 | Velocity: 10
# 2021-12 | Velocity: 11
# 2021-11 | Velocity: 8
# 2021-10 | Velocity: 18
# 2021-09 | Velocity: 9
# 2021-08 | Velocity: 20
# 2021-07 | Velocity: 12
# 2021-06 | Velocity: 19
# 2021-05 | Velocity: 11
# 2021-04 | Velocity: 24
# 2021-03 | Velocity: 31
# 2021-02 | Velocity: 21
# 2021-01 | Velocity: 27
# 2020-12 | Velocity: 29
# 2020-11 | Velocity: 31
# 2020-10 | Velocity: 9
# 2020-09 | Velocity: 21
# 2020-08 | Velocity: 45
# 2020-08 | Velocity: 19
# 2020-07 | Velocity: 15
# 2020-06 | Velocity: 4
# 2020-05 | Velocity: 6
# 2020-04 | Velocity: 3
# 2020-03 | Velocity: 4
# 2020-02 | Velocity: 8
# 2020-01 | Velocity: 6
# 2019-12 | Velocity: 5
# 2019-11 | Velocity: 9
# 2019-10 | Velocity: 6
# 2019-09 | Velocity: 6
# 2019-08 | Velocity: 7
# 2019-07 | Velocity: 7
# 2019-06 | Velocity: 2
# 2019-05 | Velocity: 1
# 2019-04 | Velocity: 3
# 2019-03 | Velocity: 2
# 2019-02 | Velocity: 3
# 2019-01 | Velocity: 3
# 2018-12 | Velocity: 8
# 2018-11 | Velocity: 12
# 2018-10 | Velocity: 2
# 2018-09 | Velocity: 4
# 2018-08 | Velocity: 10
# 2018-07 | Velocity: 6
# 2018-06 | Velocity: 12
# 2018-05 | Velocity: 1
# 2018-04 | Velocity: 8
# 2018-03 | Velocity: 12
# 2018-02 | Velocity: 9
# 2018-01 | Velocity: 10
# 2017-12 | Velocity: 6
# 2017-11 | Velocity: 15
# 2017-10 | Velocity: 5
# 2017-09 | Velocity: 8
# 2017-08 | Velocity: 8
# 2017-07 | Velocity: 7
# 2017-06 | Velocity: 9
# 2017-05 | Velocity: 16
# 2017-04 | Velocity: 10
# 2017-03 | Velocity: 12
# 2017-02 | Velocity: 9
# 2017-01 | Velocity: 14
# 2016-12 | Velocity: 13
# 2016-11 | Velocity: 14
# 2016-10 | Velocity: 9
# 2016-09 | Velocity: 18
# 2016-08 | Velocity: 9
# 2016-07 | Velocity: 17
# 2016-06 | Velocity: 32
# 2016-05 | Velocity: 14
# 2016-04 | Velocity: 13
# 2016-03 | Velocity: 3
# 2016-02 | Velocity: 13
# 2016-01 | Velocity: 14
# 2015-12 | Velocity: 13
# 2015-11 | Velocity: 15
# 2015-10 | Velocity: 7
# 2015-09 | Velocity: 10
# 2015-08 | Velocity: 11
# 2015-07 | Velocity: 7
# 2015-06 | Velocity: 5
# 2015-05 | Velocity: 2
# 2015-04 | Velocity: 8
# 2015-03 | Velocity: 5
# 2015-03 | Velocity: 5
# 2015-01 | Velocity: 7
# 2014-12 | Velocity: 10
# 2014-12 | Velocity: 8
# 2014-11 | Velocity: 11
# 2014-10 | Velocity: 9
# 2014-09 | Velocity: 10
# 2014-08 | Velocity: 14
# 2014-07 | Velocity: 2
# 2014-06 | Velocity: 11
# 2014-05 | Velocity: 13
# 2014-04 | Velocity: 10
# 2014-03 | Velocity: 9
# 2014-02 | Velocity: 22
# 2014-01 | Velocity: 5
# 2013-12 | Velocity: 9
# 2013-11 | Velocity: 7
# 2013-10 | Velocity: 5
# 2013-09 | Velocity: 9
# 2013-08 | Velocity: 7
# 2013-07 | Velocity: 3
# 2013-06 | Velocity: 9
# 2013-05 | Velocity: 12
# 2013-04 | Velocity: 12
#         Date  Raw_Velocity
# 0    2026-05             2
# 1    2026-04            14
# 2    2026-03            10
# 3    2026-02             4
# 4    2026-01             5
# ..       ...           ...
# 155  2013-08             7
# 156  2013-07             3
# 157  2013-06             9
# 158  2013-05            12
# 159  2013-04            12
#
# [160 rows x 2 columns]

# %%
results = []
lookup_df = pd.read_csv("complete_steam_lookup_2026.csv")
with open('game_list.csv', mode = 'r', newline = '') as file:
    reader = csv.reader(file)
    header = next(reader)
    for row in reader:
        app_id = find_appid(row[0], lookup_df)
        df_details = get_updates(app_id)
        df = pd.DataFrame(df_details)
        if not df.empty and 'Date' in df.columns:
            df['Date'] = pd.to_datetime(df['Date'])
            df['Game'] = row[0]
            results.append(df)
            print(df)
        else:
            print(row[0])
        time.sleep(random.uniform(2, 5))
        
update_df = pd.concat(results, axis = 0, ignore_index = True)
update_df
# Out:
# 2026-05 | Velocity: 2
# 2026-04 | Velocity: 14
# 2026-03 | Velocity: 10
# 2026-02 | Velocity: 4
# 2026-01 | Velocity: 5
# 2025-12 | Velocity: 7
# 2025-11 | Velocity: 6
# 2025-10 | Velocity: 7
# 2025-09 | Velocity: 14
# 2025-08 | Velocity: 6
# 2025-07 | Velocity: 7
# 2025-06 | Velocity: 5
# 2025-05 | Velocity: 11
# 2025-04 | Velocity: 0
# 2025-03 | Velocity: 5
# 2025-02 | Velocity: 3
# 2025-01 | Velocity: 13
# 2024-12 | Velocity: 5
# 2024-11 | Velocity: 10
# 2024-10 | Velocity: 9
# 2024-09 | Velocity: 7
# 2024-08 | Velocity: 7
# 2024-07 | Velocity: 4
# 2024-06 | Velocity: 9
# 2024-05 | Velocity: 7
# 2024-04 | Velocity: 10
# 2024-03 | Velocity: 8
# 2024-02 | Velocity: 5
# 2024-01 | Velocity: 6
# 2023-12 | Velocity: 5
# 2023-11 | Velocity: 8
# 2023-10 | Velocity: 9
# 2023-09 | Velocity: 23
# 2023-08 | Velocity: 13
# 2023-07 | Velocity: 18
# 2023-06 | Velocity: 8
# 2023-05 | Velocity: 15
# 2023-04 | Velocity: 28
# 2023-03 | Velocity: 18
# 2023-02 | Velocity: 23
# 2023-01 | Velocity: 9
# 2022-12 | Velocity: 0
# 2022-11 | Velocity: 5
# 2022-10 | Velocity: 14
# 2022-09 | Velocity: 5
# 2022-08 | Velocity: 8
# 2022-07 | Velocity: 13
# 2022-06 | Velocity: 10
# 2022-05 | Velocity: 10
# 2022-04 | Velocity: 17
# 2022-03 | Velocity: 10
# 2022-02 | Velocity: 6
# 2022-01 | Velocity: 10
# 2021-12 | Velocity: 11
# 2021-11 | Velocity: 8
# 2021-10 | Velocity: 18
# 2021-09 | Velocity: 9
# 2021-08 | Velocity: 20
# 2021-07 | Velocity: 12
# 2021-06 | Velocity: 19
# 2021-05 | Velocity: 11
# 2021-04 | Velocity: 24
# 2021-03 | Velocity: 31
# 2021-02 | Velocity: 21
# 2021-01 | Velocity: 27
# 2020-12 | Velocity: 29
# 2020-11 | Velocity: 31
# 2020-10 | Velocity: 9
# 2020-09 | Velocity: 21
# 2020-08 | Velocity: 45
# 2020-08 | Velocity: 19
# 2020-07 | Velocity: 15
# 2020-06 | Velocity: 4
# 2020-05 | Velocity: 6
# 2020-04 | Velocity: 3
# 2020-03 | Velocity: 4
# 2020-02 | Velocity: 8
# 2020-01 | Velocity: 6
# 2019-12 | Velocity: 5
# 2019-11 | Velocity: 9
# 2019-10 | Velocity: 6
# 2019-09 | Velocity: 6
# 2019-08 | Velocity: 7
# 2019-07 | Velocity: 7
# 2019-06 | Velocity: 2
# 2019-05 | Velocity: 1
# 2019-04 | Velocity: 3
# 2019-03 | Velocity: 2
# 2019-02 | Velocity: 3
# 2019-01 | Velocity: 3
# 2018-12 | Velocity: 8
# 2018-11 | Velocity: 12
# 2018-10 | Velocity: 2
# 2018-09 | Velocity: 4
# 2018-08 | Velocity: 10
# 2018-07 | Velocity: 6
# 2018-06 | Velocity: 12
# 2018-05 | Velocity: 1
# 2018-04 | Velocity: 8
# 2018-03 | Velocity: 12
# 2018-02 | Velocity: 9
# 2018-01 | Velocity: 10
# 2017-12 | Velocity: 6
# 2017-11 | Velocity: 15
# 2017-10 | Velocity: 5
# 2017-09 | Velocity: 8
# 2017-08 | Velocity: 8
# 2017-07 | Velocity: 7
# 2017-06 | Velocity: 9
# 2017-05 | Velocity: 16
# 2017-04 | Velocity: 10
# 2017-03 | Velocity: 12
# 2017-02 | Velocity: 9
# 2017-01 | Velocity: 14
# 2016-12 | Velocity: 13
# 2016-11 | Velocity: 14
# 2016-10 | Velocity: 9
# 2016-09 | Velocity: 18
# 2016-08 | Velocity: 9
# 2016-07 | Velocity: 17
# 2016-06 | Velocity: 32
# 2016-05 | Velocity: 14
# 2016-04 | Velocity: 13
# 2016-03 | Velocity: 3
# 2016-02 | Velocity: 13
# 2016-01 | Velocity: 14
# 2015-12 | Velocity: 13
# 2015-11 | Velocity: 15
# 2015-10 | Velocity: 7
# 2015-09 | Velocity: 10
# 2015-08 | Velocity: 11
# 2015-07 | Velocity: 7
# 2015-06 | Velocity: 5
# 2015-05 | Velocity: 2
# 2015-04 | Velocity: 8
# 2015-03 | Velocity: 5
# 2015-03 | Velocity: 5
# 2015-01 | Velocity: 7
# 2014-12 | Velocity: 10
# 2014-12 | Velocity: 8
# 2014-11 | Velocity: 11
# 2014-10 | Velocity: 9
# 2014-09 | Velocity: 10
# 2014-08 | Velocity: 14
# 2014-07 | Velocity: 2
# 2014-06 | Velocity: 11
# 2014-05 | Velocity: 13
# 2014-04 | Velocity: 10
# 2014-03 | Velocity: 9
# 2014-02 | Velocity: 22
# 2014-01 | Velocity: 5
# 2013-12 | Velocity: 9
# 2013-11 | Velocity: 7
# 2013-10 | Velocity: 5
# 2013-09 | Velocity: 9
# 2013-08 | Velocity: 7
# 2013-07 | Velocity: 3
# 2013-06 | Velocity: 9
# 2013-05 | Velocity: 12
# 2013-04 | Velocity: 12
#           Date  Raw_Velocity              Game
# 0   2026-05-01             2  Counter-Strike 2
# 1   2026-04-01            14  Counter-Strike 2
# 2   2026-03-01            10  Counter-Strike 2
# 3   2026-02-01             4  Counter-Strike 2
# 4   2026-01-01             5  Counter-Strike 2
# ..         ...           ...               ...
# 155 2013-08-01             7  Counter-Strike 2
# 156 2013-07-01             3  Counter-Strike 2
# 157 2013-06-01             9  Counter-Strike 2
# 158 2013-05-01            12  Counter-Strike 2
# 159 2013-04-01            12  Counter-Strike 2
#
# [160 rows x 3 columns]
# 2026-05 | Velocity: 11
# 2026-04 | Velocity: 35
# 2026-03 | Velocity: 23
# 2026-02 | Velocity: 9
# 2026-01 | Velocity: 9
# 2025-12 | Velocity: 14
# 2025-11 | Velocity: 17
# 2025-10 | Velocity: 21
# 2025-09 | Velocity: 21
# 2025-08 | Velocity: 22
# 2025-07 | Velocity: 17
# 2025-06 | Velocity: 17
# 2025-05 | Velocity: 17
# 2025-04 | Velocity: 22
# 2025-03 | Velocity: 14
# 2025-02 | Velocity: 12
# 2025-01 | Velocity: 11
# 2024-12 | Velocity: 22
# 2024-11 | Velocity: 17
# 2024-10 | Velocity: 23
# 2024-09 | Velocity: 8
# 2024-08 | Velocity: 16
# 2024-07 | Velocity: 10
# 2024-06 | Velocity: 19
# 2024-05 | Velocity: 13
# 2024-04 | Velocity: 10
# 2024-03 | Velocity: 17
# 2024-02 | Velocity: 11
# 2024-01 | Velocity: 13
# 2023-12 | Velocity: 13
# 2023-11 | Velocity: 15
# 2023-10 | Velocity: 21
# 2023-09 | Velocity: 12
# 2023-08 | Velocity: 16
# 2023-07 | Velocity: 14
# 2023-06 | Velocity: 17
# 2023-05 | Velocity: 10
# 2023-04 | Velocity: 13
# 2023-03 | Velocity: 9
# 2023-02 | Velocity: 13
# 2023-01 | Velocity: 15
# 2022-12 | Velocity: 6
# 2022-11 | Velocity: 12
# 2022-10 | Velocity: 6
# 2022-09 | Velocity: 11
# 2022-08 | Velocity: 8
# 2022-07 | Velocity: 11
# 2022-06 | Velocity: 13
# 2022-05 | Velocity: 11
# 2022-04 | Velocity: 10
# 2022-03 | Velocity: 12
# 2022-02 | Velocity: 11
# 2022-01 | Velocity: 13
# 2021-12 | Velocity: 16
# 2021-11 | Velocity: 16
# 2021-10 | Velocity: 13
# 2021-09 | Velocity: 8
# 2021-08 | Velocity: 17
# 2021-07 | Velocity: 23
# 2021-06 | Velocity: 19
# 2021-05 | Velocity: 25
# 2021-04 | Velocity: 19
# 2021-03 | Velocity: 19
# 2021-02 | Velocity: 20
# 2021-01 | Velocity: 17
# 2020-12 | Velocity: 12
# 2020-11 | Velocity: 16
# 2020-10 | Velocity: 15
# 2020-09 | Velocity: 17
# 2020-08 | Velocity: 23
# 2020-08 | Velocity: 12
# 2020-07 | Velocity: 18
# 2020-06 | Velocity: 14
# 2020-05 | Velocity: 11
# 2020-04 | Velocity: 6
# 2020-03 | Velocity: 10
# 2020-02 | Velocity: 7
# 2020-01 | Velocity: 15
# 2019-12 | Velocity: 13
# 2019-11 | Velocity: 25
# 2019-10 | Velocity: 12
# 2019-09 | Velocity: 17
# 2019-08 | Velocity: 19
# 2019-07 | Velocity: 23
# 2019-06 | Velocity: 19
# 2019-05 | Velocity: 13
# 2019-04 | Velocity: 14
# 2019-03 | Velocity: 28
# 2019-02 | Velocity: 20
# 2019-01 | Velocity: 29
# 2018-12 | Velocity: 10
# 2018-11 | Velocity: 28
# 2018-10 | Velocity: 30
# 2018-09 | Velocity: 34
# 2018-08 | Velocity: 38
# 2018-07 | Velocity: 59
# 2018-06 | Velocity: 63
# 2018-05 | Velocity: 59
# 2018-04 | Velocity: 67
# 2018-03 | Velocity: 76
# 2018-02 | Velocity: 44
# 2018-01 | Velocity: 44
# 2017-12 | Velocity: 61
# 2017-11 | Velocity: 66
# 2017-10 | Velocity: 47
# 2017-09 | Velocity: 49
# 2017-08 | Velocity: 48
# 2017-07 | Velocity: 52
# 2017-06 | Velocity: 45
# 2017-05 | Velocity: 27
# 2017-04 | Velocity: 21
# 2017-03 | Velocity: 29
# 2017-02 | Velocity: 9
# 2017-01 | Velocity: 0
# 2016-12 | Velocity: 0
# 2016-11 | Velocity: 0
# 2016-10 | Velocity: 0
# 2016-09 | Velocity: 0
# 2016-08 | Velocity: 0
# 2016-07 | Velocity: 0
# 2016-06 | Velocity: 0
# 2016-05 | Velocity: 0
# 2016-04 | Velocity: 0
# 2016-03 | Velocity: 0
# 2016-02 | Velocity: 0
# 2016-01 | Velocity: 0
# 2015-12 | Velocity: 0
# 2015-11 | Velocity: 0
# 2015-10 | Velocity: 0
# 2015-09 | Velocity: 0
#           Date  Raw_Velocity                 Game
# 0   2026-05-01            11  PUBG: BATTLEGROUNDS
# 1   2026-04-01            35  PUBG: BATTLEGROUNDS
# 2   2026-03-01            23  PUBG: BATTLEGROUNDS
# 3   2026-02-01             9  PUBG: BATTLEGROUNDS
# 4   2026-01-01             9  PUBG: BATTLEGROUNDS
# ..         ...           ...                  ...
# 125 2016-01-01             0  PUBG: BATTLEGROUNDS
# 126 2015-12-01             0  PUBG: BATTLEGROUNDS
# 127 2015-11-01             0  PUBG: BATTLEGROUNDS
# 128 2015-10-01             0  PUBG: BATTLEGROUNDS
# 129 2015-09-01             0  PUBG: BATTLEGROUNDS
#
# [130 rows x 3 columns]
# 2026-05 | Velocity: 4
# 2026-04 | Velocity: 3
# 2026-03 | Velocity: 6
# 2026-02 | Velocity: 3
# 2026-01 | Velocity: 3
# 2025-12 | Velocity: 4
# 2025-11 | Velocity: 2
# 2025-10 | Velocity: 2
# 2025-09 | Velocity: 5
# 2025-08 | Velocity: 7
# 2025-07 | Velocity: 1
# 2025-06 | Velocity: 1
# 2025-05 | Velocity: 6
# 2025-04 | Velocity: 0
# 2025-03 | Velocity: 3
# 2025-02 | Velocity: 7
# 2025-01 | Velocity: 5
# 2024-12 | Velocity: 1
# 2024-11 | Velocity: 7
# 2024-10 | Velocity: 1
# 2024-09 | Velocity: 3
# 2024-08 | Velocity: 6
# 2024-07 | Velocity: 3
# 2024-06 | Velocity: 6
# 2024-05 | Velocity: 7
# 2024-04 | Velocity: 6
# 2024-03 | Velocity: 2
# 2024-02 | Velocity: 4
# 2024-01 | Velocity: 1
# 2023-12 | Velocity: 10
# 2023-11 | Velocity: 1
# 2023-10 | Velocity: 6
# 2023-09 | Velocity: 9
# 2023-08 | Velocity: 17
# 2023-07 | Velocity: 11
# 2023-06 | Velocity: 9
# 2023-05 | Velocity: 5
# 2023-04 | Velocity: 13
# 2023-03 | Velocity: 1
# 2023-02 | Velocity: 16
# 2023-01 | Velocity: 0
# 2022-12 | Velocity: 6
# 2022-11 | Velocity: 9
# 2022-10 | Velocity: 24
# 2022-09 | Velocity: 18
# 2022-08 | Velocity: 8
# 2022-07 | Velocity: 5
# 2022-06 | Velocity: 10
# 2022-05 | Velocity: 8
# 2022-04 | Velocity: 6
# 2022-03 | Velocity: 4
# 2022-02 | Velocity: 12
# 2022-01 | Velocity: 10
# 2021-12 | Velocity: 7
# 2021-11 | Velocity: 16
# 2021-10 | Velocity: 10
# 2021-09 | Velocity: 56
# 2021-08 | Velocity: 41
# 2021-07 | Velocity: 31
# 2021-06 | Velocity: 37
# 2021-05 | Velocity: 26
# 2021-04 | Velocity: 35
# 2021-03 | Velocity: 69
# 2021-02 | Velocity: 57
# 2021-01 | Velocity: 56
# 2020-12 | Velocity: 40
# 2020-11 | Velocity: 55
# 2020-10 | Velocity: 33
# 2020-09 | Velocity: 38
# 2020-08 | Velocity: 20
# 2020-08 | Velocity: 10
# 2020-07 | Velocity: 23
# 2020-06 | Velocity: 15
# 2020-05 | Velocity: 8
# 2020-04 | Velocity: 8
# 2020-03 | Velocity: 9
# 2020-02 | Velocity: 6
# 2020-01 | Velocity: 10
# 2019-12 | Velocity: 9
# 2019-11 | Velocity: 13
# 2019-10 | Velocity: 8
# 2019-09 | Velocity: 6
# 2019-08 | Velocity: 16
# 2019-07 | Velocity: 12
# 2019-06 | Velocity: 15
# 2019-05 | Velocity: 12
# 2019-04 | Velocity: 5
# 2019-03 | Velocity: 7
# 2019-02 | Velocity: 9
# 2019-01 | Velocity: 10
# 2018-12 | Velocity: 5
# 2018-11 | Velocity: 19
# 2018-10 | Velocity: 8
# 2018-09 | Velocity: 8
# 2018-08 | Velocity: 28
# 2018-07 | Velocity: 28
# 2018-06 | Velocity: 26
# 2018-05 | Velocity: 18
# 2018-04 | Velocity: 19
# 2018-03 | Velocity: 28
# 2018-02 | Velocity: 22
# 2018-01 | Velocity: 6
# 2017-12 | Velocity: 9
# 2017-11 | Velocity: 23
# 2017-10 | Velocity: 25
# 2017-09 | Velocity: 11
# 2017-08 | Velocity: 11
# 2017-07 | Velocity: 50
# 2017-06 | Velocity: 33
# 2017-05 | Velocity: 36
# 2017-04 | Velocity: 32
# 2017-03 | Velocity: 26
# 2017-02 | Velocity: 30
# 2017-01 | Velocity: 32
# 2016-12 | Velocity: 23
# 2016-11 | Velocity: 26
# 2016-10 | Velocity: 17
# 2016-09 | Velocity: 30
# 2016-08 | Velocity: 20
# 2016-07 | Velocity: 63
# 2016-06 | Velocity: 26
# 2016-05 | Velocity: 36
# 2016-04 | Velocity: 40
# 2016-03 | Velocity: 21
# 2016-02 | Velocity: 28
# 2016-01 | Velocity: 24
# 2015-12 | Velocity: 26
# 2015-11 | Velocity: 36
# 2015-10 | Velocity: 48
# 2015-09 | Velocity: 51
# 2015-08 | Velocity: 48
# 2015-07 | Velocity: 43
# 2015-06 | Velocity: 42
# 2015-05 | Velocity: 27
# 2015-04 | Velocity: 43
# 2015-03 | Velocity: 14
# 2015-03 | Velocity: 26
# 2015-01 | Velocity: 37
# 2014-12 | Velocity: 16
# 2014-12 | Velocity: 18
# 2014-11 | Velocity: 24
# 2014-10 | Velocity: 19
# 2014-09 | Velocity: 21
# 2014-08 | Velocity: 13
# 2014-07 | Velocity: 33
# 2014-06 | Velocity: 21
# 2014-05 | Velocity: 25
# 2014-04 | Velocity: 15
# 2014-03 | Velocity: 28
# 2014-02 | Velocity: 21
# 2014-01 | Velocity: 13
# 2013-12 | Velocity: 27
# 2013-11 | Velocity: 21
# 2013-10 | Velocity: 4
# 2013-09 | Velocity: 10
# 2013-08 | Velocity: 8
# 2013-07 | Velocity: 16
# 2013-06 | Velocity: 22
# 2013-05 | Velocity: 24
# 2013-04 | Velocity: 20
#           Date  Raw_Velocity    Game
# 0   2026-05-01             4  Dota 2
# 1   2026-04-01             3  Dota 2
# 2   2026-03-01             6  Dota 2
# 3   2026-02-01             3  Dota 2
# 4   2026-01-01             3  Dota 2
# ..         ...           ...     ...
# 155 2013-08-01             8  Dota 2
# 156 2013-07-01            16  Dota 2
# 157 2013-06-01            22  Dota 2
# 158 2013-05-01            24  Dota 2
# 159 2013-04-01            20  Dota 2
#
# [160 rows x 3 columns]
# 2026-05 | Velocity: 7
# 2026-04 | Velocity: 19
# 2026-03 | Velocity: 15
# 2026-02 | Velocity: 22
# 2026-01 | Velocity: 11
# 2025-12 | Velocity: 10
# 2025-11 | Velocity: 18
# 2025-10 | Velocity: 8
# 2025-09 | Velocity: 10
# 2025-08 | Velocity: 21
# 2025-07 | Velocity: 8
# 2025-06 | Velocity: 10
# 2025-05 | Velocity: 5
# 2025-04 | Velocity: 15
# 2025-03 | Velocity: 6
# 2025-02 | Velocity: 11
# 2025-01 | Velocity: 8
# 2024-12 | Velocity: 4
# 2024-11 | Velocity: 4
# 2024-10 | Velocity: 8
# 2024-09 | Velocity: 5
# 2024-08 | Velocity: 4
# 2024-07 | Velocity: 9
# 2024-06 | Velocity: 9
# 2024-05 | Velocity: 4
# 2024-04 | Velocity: 10
# 2024-03 | Velocity: 9
# 2024-02 | Velocity: 7
# 2024-01 | Velocity: 12
# 2023-12 | Velocity: 12
# 2023-11 | Velocity: 14
# 2023-10 | Velocity: 23
# 2023-09 | Velocity: 7
# 2023-08 | Velocity: 8
# 2023-07 | Velocity: 26
# 2023-06 | Velocity: 10
# 2023-05 | Velocity: 7
# 2023-04 | Velocity: 34
# 2023-03 | Velocity: 17
# 2023-02 | Velocity: 21
# 2023-01 | Velocity: 48
# 2022-12 | Velocity: 26
# 2022-11 | Velocity: 19
# 2022-10 | Velocity: 36
# 2022-09 | Velocity: 30
# 2022-08 | Velocity: 16
# 2022-07 | Velocity: 37
# 2022-06 | Velocity: 26
# 2022-05 | Velocity: 20
# 2022-04 | Velocity: 43
# 2022-03 | Velocity: 18
# 2022-02 | Velocity: 14
# 2022-01 | Velocity: 39
# 2021-12 | Velocity: 10
# 2021-11 | Velocity: 6
# 2021-10 | Velocity: 24
# 2021-09 | Velocity: 11
# 2021-08 | Velocity: 16
# 2021-07 | Velocity: 27
# 2021-06 | Velocity: 29
# 2021-05 | Velocity: 22
# 2021-04 | Velocity: 49
# 2021-03 | Velocity: 39
# 2021-02 | Velocity: 26
# 2021-01 | Velocity: 30
# 2020-12 | Velocity: 29
# 2020-11 | Velocity: 12
# 2020-10 | Velocity: 54
# 2020-09 | Velocity: 25
# 2020-08 | Velocity: 8
# 2020-08 | Velocity: 3
# 2020-07 | Velocity: 4
#          Date  Raw_Velocity           Game
# 0  2026-05-01             7  Apex Legends™
# 1  2026-04-01            19  Apex Legends™
# 2  2026-03-01            15  Apex Legends™
# 3  2026-02-01            22  Apex Legends™
# 4  2026-01-01            11  Apex Legends™
# ..        ...           ...            ...
# 67 2020-10-01            54  Apex Legends™
# 68 2020-09-01            25  Apex Legends™
# 69 2020-08-01             8  Apex Legends™
# 70 2020-08-01             3  Apex Legends™
# 71 2020-07-01             4  Apex Legends™
#
# [72 rows x 3 columns]
# 2026-05 | Velocity: 1
# 2026-04 | Velocity: 16
# 2026-03 | Velocity: 8
# 2026-02 | Velocity: 8
# 2026-01 | Velocity: 12
# 2025-12 | Velocity: 15
# 2025-11 | Velocity: 10
# 2025-10 | Velocity: 6
# 2025-09 | Velocity: 7
# 2025-08 | Velocity: 10
# 2025-07 | Velocity: 12
# 2025-06 | Velocity: 10
# 2025-05 | Velocity: 9
# 2025-04 | Velocity: 12
# 2025-03 | Velocity: 11
# 2025-02 | Velocity: 15
# 2025-01 | Velocity: 14
# 2024-12 | Velocity: 20
# 2024-11 | Velocity: 15
# 2024-10 | Velocity: 15
# 2024-09 | Velocity: 3
# 2024-08 | Velocity: 9
# 2024-07 | Velocity: 6
# 2024-06 | Velocity: 6
#          Date  Raw_Velocity         Game
# 0  2026-05-01             1  Delta Force
# 1  2026-04-01            16  Delta Force
# 2  2026-03-01             8  Delta Force
# 3  2026-02-01             8  Delta Force
# 4  2026-01-01            12  Delta Force
# 5  2025-12-01            15  Delta Force
# 6  2025-11-01            10  Delta Force
# 7  2025-10-01             6  Delta Force
# 8  2025-09-01             7  Delta Force
# 9  2025-08-01            10  Delta Force
# 10 2025-07-01            12  Delta Force
# 11 2025-06-01            10  Delta Force
# 12 2025-05-01             9  Delta Force
# 13 2025-04-01            12  Delta Force
# 14 2025-03-01            11  Delta Force
# 15 2025-02-01            15  Delta Force
# 16 2025-01-01            14  Delta Force
# 17 2024-12-01            20  Delta Force
# 18 2024-11-01            15  Delta Force
# 19 2024-10-01            15  Delta Force
# 20 2024-09-01             3  Delta Force
# 21 2024-08-01             9  Delta Force
# 22 2024-07-01             6  Delta Force
# 23 2024-06-01             6  Delta Force
# 2026-05 | Velocity: 0
# 2026-04 | Velocity: 3
# 2026-03 | Velocity: 3
# 2026-02 | Velocity: 3
# 2026-01 | Velocity: 1
# 2025-12 | Velocity: 1
# 2025-11 | Velocity: 4
# 2025-10 | Velocity: 5
# 2025-09 | Velocity: 2
# 2025-08 | Velocity: 9
# 2025-07 | Velocity: 4
# 2025-06 | Velocity: 6
# 2025-05 | Velocity: 5
# 2025-04 | Velocity: 2
# 2025-03 | Velocity: 5
# 2025-02 | Velocity: 3
#          Date  Raw_Velocity       Game
# 0  2026-05-01             0  Bongo Cat
# 1  2026-04-01             3  Bongo Cat
# 2  2026-03-01             3  Bongo Cat
# 3  2026-02-01             3  Bongo Cat
# 4  2026-01-01             1  Bongo Cat
# 2019-06 | Velocity: 2
# 2019-05 | Velocity: 1
# 2019-04 | Velocity: 2
# 2019-03 | Velocity: 1
# 2019-02 | Velocity: 2
# 2019-01 | Velocity: 1
# 2018-12 | Velocity: 5
# 2018-11 | Velocity: 6
# 2018-10 | Velocity: 8
# 2018-09 | Velocity: 7
# 2018-08 | Velocity: 5
# 2018-07 | Velocity: 6
# 2018-06 | Velocity: 5
# 2018-05 | Velocity: 6
# 2018-04 | Velocity: 7
# 2018-03 | Velocity: 12
# 2018-02 | Velocity: 15
# 2018-01 | Velocity: 24
# 2017-12 | Velocity: 10
# 2017-11 | Velocity: 19
# 2017-10 | Velocity: 19
# 2017-09 | Velocity: 16
# 2017-08 | Velocity: 19
# 2017-07 | Velocity: 16
# 2017-06 | Velocity: 15
# 2017-05 | Velocity: 19
# 2017-04 | Velocity: 18
# 2017-03 | Velocity: 18
# 2017-02 | Velocity: 16
# 2017-01 | Velocity: 18
# 2016-12 | Velocity: 10
# 2016-11 | Velocity: 18
# 2016-10 | Velocity: 18
# 2016-09 | Velocity: 18
# 2016-08 | Velocity: 20
# 2016-07 | Velocity: 17
# 2016-06 | Velocity: 17
# 2016-05 | Velocity: 18
# 2016-04 | Velocity: 16
# 2016-03 | Velocity: 17
# 2016-02 | Velocity: 11
# 2016-01 | Velocity: 18
# 2015-12 | Velocity: 12
# 2015-11 | Velocity: 17
# 2015-10 | Velocity: 20
# 2015-09 | Velocity: 19
# 2015-08 | Velocity: 19
# 2015-07 | Velocity: 20
# 2015-06 | Velocity: 18
# 2015-05 | Velocity: 21
# 2015-04 | Velocity: 20
# 2015-03 | Velocity: 20
# 2015-03 | Velocity: 14
# 2015-01 | Velocity: 16
# 2014-12 | Velocity: 14
# 2014-12 | Velocity: 11
# 2014-11 | Velocity: 15
# 2014-10 | Velocity: 15
# 2014-09 | Velocity: 21
# 2014-08 | Velocity: 12
# 2014-07 | Velocity: 9
# 2014-06 | Velocity: 8
# 2014-05 | Velocity: 5
# 2014-04 | Velocity: 9
# 2014-03 | Velocity: 14
# 2014-02 | Velocity: 14
# 2014-01 | Velocity: 19
#           Date  Raw_Velocity  Game
# 0   2026-05-01             4  Rust
# 1   2026-04-01             6  Rust
# 2   2026-03-01             4  Rust
# 3   2026-02-01             9  Rust
# 4   2026-01-01             5  Rust
# ..         ...           ...   ...
# 146 2014-05-01             5  Rust
# 147 2014-04-01             9  Rust
# 148 2014-03-01            14  Rust
# 149 2014-02-01            14  Rust
# 150 2014-01-01            19  Rust
#
# [151 rows x 3 columns]
# 2026-05 | Velocity: 0
# 2026-04 | Velocity: 1
# 2026-03 | Velocity: 5
# 2026-02 | Velocity: 20
# 2026-01 | Velocity: 2
# 2025-12 | Velocity: 1
# 2025-11 | Velocity: 1
# 2025-10 | Velocity: 0
# 2025-09 | Velocity: 1
# 2025-08 | Velocity: 7
# 2025-07 | Velocity: 3
# 2025-06 | Velocity: 0
# 2025-05 | Velocity: 1
# 2025-04 | Velocity: 9
# 2025-03 | Velocity: 14
# 2025-02 | Velocity: 2
# 2025-01 | Velocity: 2
# 2024-12 | Velocity: 6
# 2020-09 | Velocity: 23
# 2020-08 | Velocity: 20
# 2020-08 | Velocity: 31
# 2020-07 | Velocity: 7
# 2020-06 | Velocity: 8
# 2020-05 | Velocity: 13
# 2020-04 | Velocity: 3
# 2020-03 | Velocity: 7
# 2020-02 | Velocity: 7
# 2020-01 | Velocity: 14
# 2019-12 | Velocity: 7
# 2019-11 | Velocity: 18
# 2019-10 | Velocity: 12
# 2019-09 | Velocity: 12
# 2019-08 | Velocity: 14
# 2019-07 | Velocity: 9
# 2019-06 | Velocity: 14
# 2019-05 | Velocity: 22
# 2019-04 | Velocity: 11
# 2019-03 | Velocity: 12
# 2019-02 | Velocity: 35
# 2019-01 | Velocity: 15
# 2018-12 | Velocity: 15
# 2018-11 | Velocity: 28
# 2018-10 | Velocity: 14
# 2018-09 | Velocity: 12
# 2018-08 | Velocity: 30
# 2018-07 | Velocity: 24
# 2018-06 | Velocity: 6
# 2018-05 | Velocity: 25
# 2018-04 | Velocity: 19
# 2018-03 | Velocity: 14
# 2018-02 | Velocity: 23
# 2018-01 | Velocity: 17
# 2017-12 | Velocity: 6
# 2017-11 | Velocity: 29
# 2017-10 | Velocity: 12
# 2017-09 | Velocity: 4
# 2017-08 | Velocity: 15
# 2017-07 | Velocity: 2
# 2017-06 | Velocity: 1
# 2017-05 | Velocity: 1
# 2017-04 | Velocity: 4
# 2017-03 | Velocity: 6
# 2017-02 | Velocity: 6
# 2017-01 | Velocity: 29
# 2016-12 | Velocity: 8
# 2016-11 | Velocity: 17
# 2016-10 | Velocity: 9
# 2016-09 | Velocity: 6
# 2016-08 | Velocity: 6
# 2016-07 | Velocity: 18
# 2016-06 | Velocity: 16
# 2016-05 | Velocity: 34
# 2016-04 | Velocity: 31
# 2016-03 | Velocity: 37
# 2016-02 | Velocity: 27
# 2016-01 | Velocity: 8
# 2015-12 | Velocity: 7
# 2015-11 | Velocity: 18
# 2015-10 | Velocity: 8
# 2015-09 | Velocity: 4
# 2015-08 | Velocity: 4
#           Date  Raw_Velocity                            Game
# 0   2026-05-01             3  Tom Clancy's Rainbow Six Siege
# 1   2026-04-01             4  Tom Clancy's Rainbow Six Siege
# 2   2026-03-01             5  Tom Clancy's Rainbow Six Siege
# 3   2026-02-01             8  Tom Clancy's Rainbow Six Siege
# 4   2026-01-01            10  Tom Clancy's Rainbow Six Siege
# ..         ...           ...                             ...
# 126 2015-12-01             7  Tom Clancy's Rainbow Six Siege
# 127 2015-11-01            18  Tom Clancy's Rainbow Six Siege
# 128 2015-10-01             8  Tom Clancy's Rainbow Six Siege
# 129 2015-09-01             4  Tom Clancy's Rainbow Six Siege
# 130 2015-08-01             4  Tom Clancy's Rainbow Six Siege
#
# [131 rows x 3 columns]
# 2026-05 | Velocity: 8
# 2026-04 | Velocity: 39
# 2026-03 | Velocity: 58
# 2026-02 | Velocity: 43
# 2026-01 | Velocity: 22
# 2025-12 | Velocity: 47
# 2025-11 | Velocity: 45
# 2025-10 | Velocity: 51
# 2025-09 | Velocity: 52
# 2025-08 | Velocity: 48
# 2025-07 | Velocity: 32
# 2025-06 | Velocity: 48
# 2025-05 | Velocity: 50
# 2025-04 | Velocity: 43
# 2025-03 | Velocity: 44
# 2025-02 | Velocity: 45
# 2025-01 | Velocity: 35
# 2024-12 | Velocity: 42
# 2024-11 | Velocity: 40
# 2024-10 | Velocity: 55
# 2024-09 | Velocity: 40
# 2024-08 | Velocity: 52
# 2024-07 | Velocity: 36
# 2024-06 | Velocity: 43
# 2024-05 | Velocity: 38
# 2024-04 | Velocity: 32
# 2024-03 | Velocity: 36
# 2024-02 | Velocity: 52
# 2024-01 | Velocity: 40
# 2023-12 | Velocity: 40
# 2023-11 | Velocity: 32
# 2023-10 | Velocity: 52
# 2023-09 | Velocity: 44
# 2023-08 | Velocity: 43
# 2023-07 | Velocity: 44
# 2023-06 | Velocity: 38
# 2023-05 | Velocity: 54
# 2023-04 | Velocity: 46
# 2023-03 | Velocity: 38
# 2023-02 | Velocity: 44
# 2023-01 | Velocity: 39
# 2022-12 | Velocity: 27
# 2022-11 | Velocity: 42
# 2022-10 | Velocity: 39
# 2022-09 | Velocity: 30
# 2022-08 | Velocity: 46
# 2022-07 | Velocity: 34
# 2022-06 | Velocity: 33
# 2022-05 | Velocity: 43
# 2022-04 | Velocity: 25
# 2022-03 | Velocity: 27
# 2022-02 | Velocity: 32
# 2022-01 | Velocity: 27
# 2021-12 | Velocity: 21
# 2021-11 | Velocity: 47
# 2021-10 | Velocity: 20
# 2021-09 | Velocity: 26
# 2021-08 | Velocity: 36
# 2021-07 | Velocity: 19
# 2021-06 | Velocity: 20
# 2021-05 | Velocity: 19
# 2021-04 | Velocity: 25
# 2021-03 | Velocity: 18
# 2021-02 | Velocity: 22
# 2021-01 | Velocity: 19
# 2020-12 | Velocity: 5
# 2020-11 | Velocity: 17
# 2020-10 | Velocity: 33
# 2020-09 | Velocity: 18
# 2020-08 | Velocity: 22
# 2020-08 | Velocity: 19
# 2020-07 | Velocity: 19
# 2020-06 | Velocity: 23
# 2020-05 | Velocity: 31
# 2020-04 | Velocity: 13
# 2020-03 | Velocity: 29
# 2020-02 | Velocity: 19
# 2020-01 | Velocity: 7
# 2019-12 | Velocity: 15
# 2019-11 | Velocity: 8
# 2019-10 | Velocity: 22
# 2019-09 | Velocity: 19
# 2019-08 | Velocity: 24
# 2019-07 | Velocity: 8
# 2019-06 | Velocity: 5
# 2019-05 | Velocity: 21
# 2019-04 | Velocity: 7
# 2019-03 | Velocity: 10
# 2019-02 | Velocity: 29
# 2019-01 | Velocity: 4
# 2018-12 | Velocity: 19
# 2018-11 | Velocity: 14
# 2018-10 | Velocity: 19
# 2018-09 | Velocity: 9
# 2018-08 | Velocity: 19
# 2018-07 | Velocity: 7
# 2018-06 | Velocity: 13
# 2018-05 | Velocity: 22
# 2018-04 | Velocity: 4
# 2018-03 | Velocity: 16
# 2018-02 | Velocity: 49
# 2018-01 | Velocity: 18
# 2017-12 | Velocity: 19
# 2017-11 | Velocity: 34
# 2017-10 | Velocity: 30
# 2017-09 | Velocity: 14
# 2017-08 | Velocity: 54
# 2017-07 | Velocity: 17
# 2017-06 | Velocity: 16
# 2017-05 | Velocity: 22
# 2017-04 | Velocity: 42
# 2017-03 | Velocity: 20
# 2017-02 | Velocity: 40
# 2017-01 | Velocity: 22
# 2016-12 | Velocity: 31
# 2016-11 | Velocity: 37
# 2016-10 | Velocity: 32
# 2016-09 | Velocity: 14
# 2016-08 | Velocity: 37
# 2016-07 | Velocity: 37
# 2016-06 | Velocity: 20
# 2016-05 | Velocity: 30
# 2016-04 | Velocity: 26
# 2016-03 | Velocity: 20
# 2016-02 | Velocity: 46
# 2016-01 | Velocity: 50
# 2015-12 | Velocity: 28
# 2015-11 | Velocity: 50
# 2015-10 | Velocity: 25
# 2015-09 | Velocity: 30
# 2015-08 | Velocity: 44
# 2015-07 | Velocity: 37
# 2015-06 | Velocity: 39
# 2015-05 | Velocity: 66
# 2015-04 | Velocity: 60
# 2015-03 | Velocity: 89
# 2015-03 | Velocity: 58
# 2015-01 | Velocity: 80
# 2014-12 | Velocity: 61
# 2014-12 | Velocity: 91
# 2014-11 | Velocity: 42
# 2014-10 | Velocity: 75
# 2014-09 | Velocity: 109
# 2014-08 | Velocity: 100
# 2014-07 | Velocity: 80
# 2014-06 | Velocity: 109
# 2014-05 | Velocity: 80
# 2014-04 | Velocity: 49
# 2014-03 | Velocity: 44
# 2014-02 | Velocity: 39
# 2014-01 | Velocity: 35
# 2013-12 | Velocity: 32
# 2013-11 | Velocity: 41
# 2013-10 | Velocity: 36
# 2013-09 | Velocity: 23
#           Date  Raw_Velocity         Game
# 0   2026-05-01             8  War Thunder
# 1   2026-04-01            39  War Thunder
# 2   2026-03-01            58  War Thunder
# 3   2026-02-01            43  War Thunder
# 4   2026-01-01            22  War Thunder
# ..         ...           ...          ...
# 150 2014-01-01            35  War Thunder
# 151 2013-12-01            32  War Thunder
# 152 2013-11-01            41  War Thunder
# 153 2013-10-01            36  War Thunder
# 154 2013-09-01            23  War Thunder
#
# [155 rows x 3 columns]
# 2026-05 | Velocity: 1
# 2026-04 | Velocity: 14
# 2026-03 | Velocity: 15
# 2026-02 | Velocity: 15
# 2026-01 | Velocity: 9
# 2025-12 | Velocity: 10
# 2025-11 | Velocity: 15
# 2025-10 | Velocity: 19
# 2025-09 | Velocity: 9
# 2025-08 | Velocity: 10
# 2025-07 | Velocity: 15
# 2025-06 | Velocity: 13
# 2025-05 | Velocity: 15
# 2025-04 | Velocity: 9
# 2025-03 | Velocity: 20
# 2025-02 | Velocity: 17
# 2025-01 | Velocity: 13
# 2024-12 | Velocity: 18
# 2024-11 | Velocity: 23
# 2024-10 | Velocity: 14
# 2024-09 | Velocity: 16
# 2024-08 | Velocity: 10
# 2024-07 | Velocity: 29
# 2024-06 | Velocity: 11
# 2024-05 | Velocity: 12
# 2024-04 | Velocity: 10
# 2024-03 | Velocity: 16
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 8
#       6 for row in reader:
#       7     app_id = find_appid(row[0], lookup_df)
# ----> 8     df_details = get_updates(app_id)
#       9     df = pd.DataFrame(df_details)
#      10     if not df.empty and 'Date' in df.columns:
#
# Cell In[22], line 19, in get_updates(appid, max_window)
#      17 try:
#      18     time.sleep(0.5)
# ---> 19     response = requests.get(base_url, params=params)
#      20     data = response.json()
#      21     current_total_count = data['appnews']['count']
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     513 _shutdown = getattr(self.sock, "shutdown", None)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#     519     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:
